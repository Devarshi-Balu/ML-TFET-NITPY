# %%
import pandas as pd 

df = pd.read_csv("main_dataset.csv")

# %%
for feature in df.columns :
    print(feature)
    print(df[feature].unique())
    print("No.of Unique values = ", len(df[feature].unique()))
    print("-------")
# Out:
# Tsi
# [10]
# No.of Unique values =  1
# -------
# Tox
# [1 3 2]
# No.of Unique values =  3
# -------
# Ns
# [1.e+17 5.e+17 1.e+16 5.e+16 1.e+18 5.e+18 1.e+19 5.e+19 1.e+20]
# No.of Unique values =  9
# -------
# Nc
# [100000000000000000  10000000000000000]
# No.of Unique values =  2
# -------
# Nd
# [1.e+16 1.e+20 5.e+16 1.e+17 5.e+17 1.e+18 5.e+18 1.e+19 5.e+19]
# No.of Unique values =  9
# -------
# Vds
# [0.2 0.4 0.6 0.8 0.  1. ]
# No.of Unique values =  6
# -------
# Vgs
# [0.         0.002      0.00573333 ... 1.9709511  1.9809511  1.9909511 ]
# No.of Unique values =  1817
# -------
# Id
# [1.050000e-17 1.040000e-17 4.100000e-18 ... 2.355223e-03 3.170000e-20
#  8.980000e-10]
# No.of Unique values =  100412
# -------

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Load dataset
# df = pd.read_csv("main_dataset.csv")

# # Define plot function to check each parameter's impact on Id
# def plot_id_dependency(df, feature, id_column='Id'):
#     plt.figure(figsize=(8, 5))
#     sns.scatterplot(data=df, x=feature, y=id_column)
#     plt.title(f'Effect of {feature} on Id')
#     plt.xlabel(feature)
#     plt.ylabel('Drain Current (Id)')
#     plt.yscale('log')  # Use log scale for better visibility if Id spans large ranges
#     plt.show()

# # Parameters to explore
# features = ['Tsi', 'Tox', 'Ns', 'Nc', 'Nd', 'Vds', 'Vgs']

# # Plot each feature against Id
# for feature in features:
#     plot_id_dependency(df, feature)

# %%
df2 = pd.read_csv("test_data.csv")

for feature in df2.columns:
    print(feature)
    print(df2[feature].unique())
    print("No.of Unique values = ", len(df2[feature].unique()))
    print("-------")
# Out:
# Tsi
# [10]
# No.of Unique values =  1
# -------
# Tox
# [2.5 1.5 1.  3. ]
# No.of Unique values =  4
# -------
# Ns
# [1.e+20 2.e+19 1.e+17 5.e+19]
# No.of Unique values =  4
# -------
# Nc
# [1.e+17 1.e+16]
# No.of Unique values =  2
# -------
# Nd
# [5.e+18 2.e+18 1.e+16 5.e+19]
# No.of Unique values =  4
# -------
# Vds
# [0.5 0.2 1. ]
# No.of Unique values =  3
# -------
# Vgs
# [0.         0.002      0.00573333 0.01295111 0.02295111 0.03295111
#  0.04295111 0.05295111 0.06295111 0.07295111 0.08295111 0.09295111
#  0.10295111 0.11295111 0.12295111 0.13295111 0.14295111 0.15295111
#  0.16295111 0.17295111 0.18295111 0.19295111 0.20295111 0.21295111
#  0.22295111 0.23295111 0.24295111 0.25295111 0.26295111 0.27295111
#  0.28295111 0.29295111 0.30295111 0.31295111 0.32295111 0.33295111
#  0.34295111 0.35295111 0.36295111 0.37295111 0.38295111 0.39295111
#  0.40295111 0.41295111 0.42295111 0.43295111 0.44295111 0.45295111
# ...

# %%
# filtered_df = df[(df['Id'] >= 1e-9) & (df['Id'] <= 1e-1 )]

# print(filtered_df)
# filtered_df.describe()

# %%
# import matplotlib.pyplot as plt 
# plt.scatter(filtered_df['Vgs'], filtered_df["Id"])

# %%
## pulling out data were Tox = 2.5 , Ns = 2*1e19, Nc = 1*1e17, Nd = 2*e18 
## pulling out data were Tox = 1.5 , Ns = 2*1e19, Nc = 1*1e17, Nd = 2*e18

# %%
# df[(df["Tox"] == 1)]

# %%
# df[(df["Tox"] == 3)]

# %%
import sys
sys.path.append("C:/Users/studi/Desktop/machine learning/_ ml _ internship/global")

from functions import select_experiment
# the above function "select_experiment" is not an inbuilt function, This is function is defined to extract the specific experiments from the test dataset, 
# this is a part of the userdefined module function present in the directory global in the above path 
x_test_2, y_test_2, Vgs_2 = select_experiment(2)
x_test_3, y_test_3, Vgs_3 = select_experiment(3)

# %%
x_test_1, y_test_1, Vgs_1 = select_experiment(1)
print(x_test_1.describe())

# in test experiment - 1:  
# seen : (Tsi, Ns, Nc, Nd)
# Unseen : (Tox = 2.5,Vds = 0.4)
# Out:
#          Tsi    Tox            Ns            Nc            Nd    Vds  \
# count  203.0  203.0  2.030000e+02  2.030000e+02  2.030000e+02  203.0
# mean    10.0    2.5  1.000000e+20  1.000000e+17  5.000000e+18    0.5
# std      0.0    0.0  5.584331e+05  0.000000e+00  0.000000e+00    0.0
# min     10.0    2.5  1.000000e+20  1.000000e+17  5.000000e+18    0.5
# 25%     10.0    2.5  1.000000e+20  1.000000e+17  5.000000e+18    0.5
# 50%     10.0    2.5  1.000000e+20  1.000000e+17  5.000000e+18    0.5
# 75%     10.0    2.5  1.000000e+20  1.000000e+17  5.000000e+18    0.5
# max     10.0    2.5  1.000000e+20  1.000000e+17  5.000000e+18    0.5
#
#               Vgs
# count  203.000000
# mean     0.993079
# std      0.587184
# min      0.000000
# 25%      0.487951
# 50%      0.992951
# 75%      1.497951
# max      2.000000

# %%
print(x_test_2.describe())

# in test experiment - 2 :
# seen   :  Nc, Tsi
# Unseen : Tox, Ns, Nd, Vds   are never seen by the model during training
# Out:
#          Tsi    Tox            Ns            Nc            Nd    Vds  \
# count  203.0  203.0  2.030000e+02  2.030000e+02  2.030000e+02  203.0
# mean    10.0    2.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# std      0.0    0.0  0.000000e+00  0.000000e+00  0.000000e+00    0.0
# min     10.0    2.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# 25%     10.0    2.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# 50%     10.0    2.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# 75%     10.0    2.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# max     10.0    2.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
#
#               Vgs
# count  203.000000
# mean     0.993079
# std      0.587184
# min      0.000000
# 25%      0.487951
# 50%      0.992951
# 75%      1.497951
# max      2.000000

# %%
x_test_3, y_test_3, Vgs_3 = select_experiment(3)
print(x_test_3.describe())

# in test experiment - 3:  
# seen : ( Tsi, Nc = 1e17 )
# Unseen : (Tox = 1.5,  Nd = 2*1e18, Ns = 2e19, Vds = 0.5 )
# Out:
#          Tsi    Tox            Ns            Nc            Nd    Vds  \
# count  203.0  203.0  2.030000e+02  2.030000e+02  2.030000e+02  203.0
# mean    10.0    1.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# std      0.0    0.0  0.000000e+00  0.000000e+00  0.000000e+00    0.0
# min     10.0    1.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# 25%     10.0    1.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# 50%     10.0    1.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# 75%     10.0    1.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
# max     10.0    1.5  2.000000e+19  1.000000e+17  2.000000e+18    0.5
#
#               Vgs
# count  203.000000
# mean     0.993079
# std      0.587184
# min      0.000000
# 25%      0.487951
# 50%      0.992951
# 75%      1.497951
# max      2.000000

# %%
x_test_4, y_test_4, Vgs_4 = select_experiment(4)
print(x_test_4.describe())

# in test experiment - 4:  
# seen : (Tox = 1, Ns = 1e17 , Nc = 1e17, Vds = 0.2, Nd = 1e16, Vds = 0.2)
# Unseen : Nothing
# Out:
#          Tsi    Tox            Ns            Nc            Nd           Vds  \
# count  203.0  203.0  2.030000e+02  2.030000e+02  2.030000e+02  2.030000e+02
# mean    10.0    1.0  1.000000e+17  1.000000e+17  1.000000e+16  2.000000e-01
# std      0.0    0.0  0.000000e+00  0.000000e+00  0.000000e+00  1.669452e-16
# min     10.0    1.0  1.000000e+17  1.000000e+17  1.000000e+16  2.000000e-01
# 25%     10.0    1.0  1.000000e+17  1.000000e+17  1.000000e+16  2.000000e-01
# 50%     10.0    1.0  1.000000e+17  1.000000e+17  1.000000e+16  2.000000e-01
# 75%     10.0    1.0  1.000000e+17  1.000000e+17  1.000000e+16  2.000000e-01
# max     10.0    1.0  1.000000e+17  1.000000e+17  1.000000e+16  2.000000e-01
#
#               Vgs
# count  203.000000
# mean     0.993323
# std      0.587188
# min      0.000000
# 25%      0.488200
# 50%      0.993200
# 75%      1.498200
# max      2.000000

# %%
x_test_5, y_test_5, Vgs_5 = select_experiment(5)
print(x_test_5.describe())

# in test experiment - 5:  
# seen : (Tox = 3, Ns = 5e19 , Nc = 1e16, Vds = 1.0, Nd = 5e19, Vds = 0.2)
# Unseen : Nothing
# Out:
#          Tsi    Tox            Ns            Nc            Nd    Vds  \
# count  203.0  203.0  2.030000e+02  2.030000e+02  2.030000e+02  203.0
# mean    10.0    3.0  5.000000e+19  1.000000e+16  5.000000e+19    1.0
# std      0.0    0.0  2.792166e+05  0.000000e+00  2.792166e+05    0.0
# min     10.0    3.0  5.000000e+19  1.000000e+16  5.000000e+19    1.0
# 25%     10.0    3.0  5.000000e+19  1.000000e+16  5.000000e+19    1.0
# 50%     10.0    3.0  5.000000e+19  1.000000e+16  5.000000e+19    1.0
# 75%     10.0    3.0  5.000000e+19  1.000000e+16  5.000000e+19    1.0
# max     10.0    3.0  5.000000e+19  1.000000e+16  5.000000e+19    1.0
#
#               Vgs
# count  203.000000
# mean     0.993079
# std      0.587184
# min      0.000000
# 25%      0.487951
# 50%      0.992951
# 75%      1.497951
# max      2.000000

# %%
df[(df["Tox"] == 1.5) | (df['Tox'] == 2.5) | (df['Ns'] == 2*1e20)  ]

## pulling out data were Tox = 2.5 , Ns = 2*1e19, Nc = 1*1e17, Nd = 2*e18 
## pulling out data were Tox = 1.5 , Ns = 2*1e19, Nc = 1*1e17, Nd = 2*e18
# Out:
# Empty DataFrame
# Columns: [Tsi, Tox, Ns, Nc, Nd, Vds, Vgs, Id]
# Index: []

# %%
print("length = 10^-16 = ",len(df[(df['Id']  >= 1e-16) & (df['Id'] < 1e-15)]['Id'].tolist()))

# for x in df[(df['Id'] > 1e-16) & (df['Id'] < 1.99e-16)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-16 =  67995

# %%
print("length = 10^-17 = ",len(df[(df['Id'] >= 1e-17) & (df['Id'] < 1e-16)]['Id'].tolist()))

# for x in df[(df['Id'] >= 1e-17) & (df['Id'] < 1e-16)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-17 =  123253

# %%
print("length = 10^-18 = ",len(df[(df['Id'] >= 1e-18) & (df['Id'] < 1e-17)]['Id'].tolist()))

# for x in df[(df['Id'] >= 1e-18) & (df['Id'] < 1e-17)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-18 =  145429

# %%
print("length = 10^-19 = ",len(df[(df['Id'] >= 1e-19) & (df['Id'] < 1e-18)]['Id'].tolist()))

# for x in df[(df['Id'] >= 1e-18) & (df['Id'] < 1e-17)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-19 =  32927

# %%
print("length = 10^-20 = ",len(df[(df['Id'] >= 1e-20) & (df['Id'] < 1e-19)]['Id'].tolist()))

# for x in df[(df['Id'] >= 1e-18) & (df['Id'] < 1e-17)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-20 =  18993

# %%
print("length = 10^-21 = ",len(df[(df['Id'] >= 1e-21) & (df['Id'] < 1e-20)]['Id'].tolist()))

# for x in df[(df['Id'] >= 1e-18) & (df['Id'] < 1e-17)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-21 =  4150

# %%
print("length = 10^-22 = ",len(df[(df['Id'] >= 1e-22) & (df['Id'] < 1e-21)]['Id'].tolist()))

# for x in df[(df['Id'] >= 1e-18) & (df['Id'] < 1e-17)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-22 =  440

# %%
print("length = 10^-23 = ",len(df[(df['Id'] >= 1e-23) & (df['Id'] < 1e-22)]['Id'].tolist()))

# for x in df[(df['Id'] >= 1e-18) & (df['Id'] < 1e-17)]['Id'].unique().tolist():
#     print(x)
# Out:
# length = 10^-23 =  37

# %%
import matplotlib.pyplot as plt 

x = list(range(0, len(df[df["Id"] < 1e-16]['Id'].tolist())))
y = df[df["Id"] < 1e-16]['Id'].tolist()

plt.semilogy(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np


# splitting the data based on ranges
data_10_16 = df[(df["Id"] >= 1e-16) & (df["Id"] <= 1e-15)]
data_10_17 = df[(df["Id"] >= 1e-17) & (df["Id"] < 1e-16)]
data_10_18 = df[(df["Id"] >= 1e-18 ) & (df["Id"] < 1e-17)]
data_10_19 = df[(df["Id"] >= 1e-19 ) & (df["Id"] < 1e-18)]
data_10_20 = df[(df["Id"] >= 1e-20 ) & (df["Id"] < 1e-19)]
data_10_21 = df[(df["Id"] >= 1e-21 ) & (df["Id"] < 1e-20)]
data_10_22 = df[(df["Id"] >= 1e-22 ) & (df["Id"] < 1e-21)]


# Generate x values for each range
x_10_16 = list(range(len(data_10_16)))
x_10_17 = list(range(len(data_10_17)))
x_10_18 = list(range(len(data_10_18)))
x_10_19 = list(range(len(data_10_19)))
x_10_20 = list(range(len(data_10_20)))
x_10_21 = list(range(len(data_10_21)))
x_10_22 = list(range(len(data_10_22)))


#plotting 
plt.plot(x_10_16, np.log10(data_10_16['Id'].tolist()), label="10^-16", color="blue")
plt.plot(x_10_17, np.log10(data_10_17['Id'].tolist()), label="10^-17", color="green")
plt.plot(x_10_18, np.log10(data_10_18['Id'].tolist()), label="10^-18", color="red")
plt.plot(x_10_19, np.log10(data_10_19['Id'].tolist()), label="10^-19", color="violet")
plt.plot(x_10_20, np.log10(data_10_20['Id'].tolist()), label="10^-20", color="indigo")
plt.plot(x_10_21, np.log10(data_10_21['Id'].tolist()), label="10^-21", color="yellow")
plt.plot(x_10_22, np.log10(data_10_22['Id'].tolist()), label="10^-22", color="orange")

# Add additional colors as needed

# Adding labels and legend
plt.xlabel("No.of Values")
plt.ylabel("Id (log scale)")
plt.legend()
plt.show()

# %%
# Separate the data based on ranges
plt.figure(figsize = (20, 12))
data_10_16 = df[(df["Id"] >= 1e-16) & (df["Id"] < 1e-15)]
data_10_15 = df[(df["Id"] >= 1e-15) & (df["Id"] < 1e-14)]
data_10_14 = df[(df["Id"] >= 1e-14) & (df["Id"] < 1e-13)]
data_10_13 = df[(df["Id"] >= 1e-13) & (df["Id"] < 1e-12)]
data_10_12 = df[(df["Id"] >= 1e-12) & (df["Id"] < 1e-11)]
data_10_11 = df[(df["Id"] >= 1e-11) & (df["Id"] < 1e-10)]
data_10_10 = df[(df["Id"] >= 1e-10) & (df["Id"] < 1e-9)]
data_10_9  = df[(df["Id"] >= 1e-9) & (df["Id"] < 1e-8)]
data_10_8  = df[(df["Id"] >= 1e-8) & (df["Id"] < 1e-7)]
data_10_7  = df[(df["Id"] >= 1e-7) & (df["Id"] < 1e-6)]
data_10_6  = df[(df["Id"] >= 1e-6) & (df["Id"] < 1e-5)]
data_10_5  = df[(df["Id"] >= 1e-5) & (df["Id"] < 1e-4)]
data_10_4  = df[(df["Id"] >= 1e-4) & (df["Id"] < 1e-3)]
data_10_3  = df[(df["Id"] >= 1e-3) & (df["Id"] < 1e-2)]
data_10_2  = df[(df["Id"] >= 1e-2) & (df["Id"] < 1e-1)]
data_10_1  = df[(df["Id"] >= 1e-1) & (df["Id"] < 1)]

# Generate x values for each range
x_10_16 = list(range(len(data_10_16)))
x_10_15 = list(range(len(data_10_15)))
x_10_14 = list(range(len(data_10_14)))
x_10_13 = list(range(len(data_10_13)))
x_10_12 = list(range(len(data_10_12)))
x_10_11 = list(range(len(data_10_11)))
x_10_10 = list(range(len(data_10_10)))
x_10_9  = list(range(len(data_10_9)))
x_10_8  = list(range(len(data_10_8)))
x_10_7  = list(range(len(data_10_7)))
x_10_6  = list(range(len(data_10_6)))
x_10_5  = list(range(len(data_10_5)))
x_10_4  = list(range(len(data_10_4)))
x_10_3  = list(range(len(data_10_3)))
x_10_2  = list(range(len(data_10_2)))
x_10_1  = list(range(len(data_10_1)))

# Plot each range with a different color
plt.semilogy(x_10_15, data_10_15['Id'].tolist(), label="10^-15", color="green")
plt.semilogy(x_10_14, data_10_14['Id'].tolist(), label="10^-14", color="red")
plt.semilogy(x_10_13, data_10_13['Id'].tolist(), label="10^-13", color="purple")
plt.semilogy(x_10_12, data_10_12['Id'].tolist(), label="10^-12", color="orange")
plt.semilogy(x_10_11, data_10_11['Id'].tolist(), label="10^-11", color="pink")
plt.semilogy(x_10_10, data_10_10['Id'].tolist(), label="10^-10", color="brown")
plt.semilogy(x_10_9, data_10_9['Id'].tolist(), label="10^-9", color="gray")
plt.semilogy(x_10_8, data_10_8['Id'].tolist(), label="10^-8", color="cyan")
plt.semilogy(x_10_7, data_10_7['Id'].tolist(), label="10^-7", color="magenta")
plt.semilogy(x_10_6, data_10_6['Id'].tolist(), label="10^-6", color="lime")
plt.semilogy(x_10_5, data_10_5['Id'].tolist(), label="10^-5", color="olive")
plt.semilogy(x_10_4, data_10_4['Id'].tolist(), label="10^-4", color="teal")
plt.semilogy(x_10_3, data_10_3['Id'].tolist(), label="10^-3", color="navy")
plt.semilogy(x_10_2, data_10_2['Id'].tolist(), label="10^-2", color="maroon")
plt.semilogy(x_10_1, data_10_1['Id'].tolist(), label="10^-1", color="gold")

# Adding labels and legend
plt.xlabel("Index")
plt.ylabel("Id (log scale)")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 20))
# Separate the data based on ranges from 10^-24 up to 10^-1
data_10_24 = df[(df["Id"] >= 1e-24) & (df["Id"] < 1e-23)]
data_10_23 = df[(df["Id"] >= 1e-23) & (df["Id"] < 1e-22)]
data_10_22 = df[(df["Id"] >= 1e-22) & (df["Id"] < 1e-21)]
data_10_21 = df[(df["Id"] >= 1e-21) & (df["Id"] < 1e-20)]
data_10_20 = df[(df["Id"] >= 1e-20) & (df["Id"] < 1e-19)]
data_10_19 = df[(df["Id"] >= 1e-19) & (df["Id"] < 1e-18)]
data_10_18 = df[(df["Id"] >= 1e-18) & (df["Id"] < 1e-17)]
data_10_17 = df[(df["Id"] >= 1e-17) & (df["Id"] < 1e-16)]
data_10_16 = df[(df["Id"] >= 1e-16) & (df["Id"] < 1e-15)]
data_10_15 = df[(df["Id"] >= 1e-15) & (df["Id"] < 1e-14)]
data_10_14 = df[(df["Id"] >= 1e-14) & (df["Id"] < 1e-13)]
data_10_13 = df[(df["Id"] >= 1e-13) & (df["Id"] < 1e-12)]
data_10_12 = df[(df["Id"] >= 1e-12) & (df["Id"] < 1e-11)]
data_10_11 = df[(df["Id"] >= 1e-11) & (df["Id"] < 1e-10)]
data_10_10 = df[(df["Id"] >= 1e-10) & (df["Id"] < 1e-9)]
data_10_9  = df[(df["Id"] >= 1e-9) & (df["Id"] < 1e-8)]
data_10_8  = df[(df["Id"] >= 1e-8) & (df["Id"] < 1e-7)]
data_10_7  = df[(df["Id"] >= 1e-7) & (df["Id"] < 1e-6)]
data_10_6  = df[(df["Id"] >= 1e-6) & (df["Id"] < 1e-5)]
data_10_5  = df[(df["Id"] >= 1e-5) & (df["Id"] < 1e-4)]
data_10_4  = df[(df["Id"] >= 1e-4) & (df["Id"] < 1e-3)]
data_10_3  = df[(df["Id"] >= 1e-3) & (df["Id"] < 1e-2)]
data_10_2  = df[(df["Id"] >= 1e-2) & (df["Id"] < 1e-1)]
data_10_1  = df[(df["Id"] >= 1e-1) & (df["Id"] < 1)]

# Generate x values for each range
x_10_24 = list(range(len(data_10_24)))
x_10_23 = list(range(len(data_10_23)))
x_10_22 = list(range(len(data_10_22)))
x_10_21 = list(range(len(data_10_21)))
x_10_20 = list(range(len(data_10_20)))
x_10_19 = list(range(len(data_10_19)))
x_10_18 = list(range(len(data_10_18)))
x_10_17 = list(range(len(data_10_17)))
x_10_16 = list(range(len(data_10_16)))
x_10_15 = list(range(len(data_10_15)))
x_10_14 = list(range(len(data_10_14)))
x_10_13 = list(range(len(data_10_13)))
x_10_12 = list(range(len(data_10_12)))
x_10_11 = list(range(len(data_10_11)))
x_10_10 = list(range(len(data_10_10)))
x_10_9  = list(range(len(data_10_9)))
x_10_8  = list(range(len(data_10_8)))
x_10_7  = list(range(len(data_10_7)))
x_10_6  = list(range(len(data_10_6)))
x_10_5  = list(range(len(data_10_5)))
x_10_4  = list(range(len(data_10_4)))
x_10_3  = list(range(len(data_10_3)))
x_10_2  = list(range(len(data_10_2)))
x_10_1  = list(range(len(data_10_1)))

# Plot each range with a different color
plt.semilogy(x_10_24, data_10_24['Id'].tolist(), label="10^-24", color="purple")
plt.semilogy(x_10_23, data_10_23['Id'].tolist(), label="10^-23", color="blue")
plt.semilogy(x_10_22, data_10_22['Id'].tolist(), label="10^-22", color="cyan")
plt.semilogy(x_10_21, data_10_21['Id'].tolist(), label="10^-21", color="green")
plt.semilogy(x_10_20, data_10_20['Id'].tolist(), label="10^-20", color="lime")
plt.semilogy(x_10_19, data_10_19['Id'].tolist(), label="10^-19", color="yellow")
plt.semilogy(x_10_18, data_10_18['Id'].tolist(), label="10^-18", color="orange")
plt.semilogy(x_10_17, data_10_17['Id'].tolist(), label="10^-17", color="red")
plt.semilogy(x_10_16, data_10_16['Id'].tolist(), label="10^-16", color="pink")
plt.semilogy(x_10_15, data_10_15['Id'].tolist(), label="10^-15", color="purple")
plt.semilogy(x_10_14, data_10_14['Id'].tolist(), label="10^-14", color="blue")
plt.semilogy(x_10_13, data_10_13['Id'].tolist(), label="10^-13", color="cyan")
plt.semilogy(x_10_12, data_10_12['Id'].tolist(), label="10^-12", color="green")
plt.semilogy(x_10_11, data_10_11['Id'].tolist(), label="10^-11", color="lime")
plt.semilogy(x_10_10, data_10_10['Id'].tolist(), label="10^-10", color="yellow")
plt.semilogy(x_10_9, data_10_9['Id'].tolist(), label="10^-9", color="orange")
plt.semilogy(x_10_8, data_10_8['Id'].tolist(), label="10^-8", color="red")
plt.semilogy(x_10_7, data_10_7['Id'].tolist(), label="10^-7", color="pink")
plt.semilogy(x_10_6, data_10_6['Id'].tolist(), label="10^-6", color="purple")
plt.semilogy(x_10_5, data_10_5['Id'].tolist(), label="10^-5", color="blue")
plt.semilogy(x_10_4, data_10_4['Id'].tolist(), label="10^-4", color="cyan")
plt.semilogy(x_10_3, data_10_3['Id'].tolist(), label="10^-3", color="green")
plt.semilogy(x_10_2, data_10_2['Id'].tolist(), label="10^-2", color="lime")
plt.semilogy(x_10_1, data_10_1['Id'].tolist(), label="10^-1", color="yellow")

# Adding labels and legend
plt.xlabel("Index")
plt.ylabel("Id (log scale)")
plt.legend(ncol=2, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
